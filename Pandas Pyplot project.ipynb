# %%
# Import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(color_codes=True)

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
# Load the car.csv dataset

car = pd.read_csv("car-sales.csv")
car.head()
# Out:
#      Make Colour  Odometer  Door     price
# 0  Toyota  White    150043     4   $4,000
# 1   Honda    Red     87899     4   $5,000
# 2  Toyota   Blue     32549     3   $7,000
# 3     BMW  Black     11179     5  $22,000
# 4  Nissan  White    213095     4   $3,500

# %%
car.dtypes
# Out:
# Make        object
# Colour      object
# Odometer     int64
# Door         int64
# price       object
# dtype: object

# %%
car.columns
# Out:
# Index(['Make', 'Colour', 'Odometer', 'Door', 'price'], dtype='object')

# %%
# Analytical summary of dataset
car.describe(include='all')
# Out:
#           Make Colour       Odometer       Door    price
# count       10     10      10.000000  10.000000       10
# unique       4      5            NaN        NaN        9
# top     Toyota  White            NaN        NaN  $7,000
# freq         4      4            NaN        NaN        2
# mean       NaN    NaN   78601.400000   4.000000      NaN
# std        NaN    NaN   61983.471735   0.471405      NaN
# min        NaN    NaN   11179.000000   3.000000      NaN
# 25%        NaN    NaN   35836.250000   4.000000      NaN
# 50%        NaN    NaN   57369.000000   4.000000      NaN
# 75%        NaN    NaN   96384.500000   4.000000      NaN
# max        NaN    NaN  213095.000000   5.000000      NaN

# %%
car.hist(figsize=(40,50))
# Out:
# array([[<Axes: title={'center': 'Odometer'}>,
#         <Axes: title={'center': 'Door'}>]], dtype=object)

# %%
# Relationship between categorical and continous variable
sns.boxplot(x = "Make", y = "price", data = car)
# Out:
# <Axes: xlabel='Make', ylabel='price'>

# %%
sns.pairplot(car)
# Out:
# C:\users\admin\desktop\my_project\env\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
